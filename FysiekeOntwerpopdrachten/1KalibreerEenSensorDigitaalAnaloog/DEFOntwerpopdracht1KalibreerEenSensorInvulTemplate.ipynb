# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 55     |  |
# | :-------------|:-------------|
# | Isha Schneiders| 6384838 |
# | Celeste de Jong| 6290728 |
# | Roosmarijn Kos| 6460097 |
#
# | Planning Groep: 55     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 12:30 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 16:00 |
# | Pauze 1| TU pauze |
# | Pauze 2| eigen invulling |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# <img src="thermistor.jpeg" width="400">
# <img src="LDR.jpeg" width="400">
# <img src="druksensor.jpeg" width="400">

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |thermistor | kamertemperatuur meten voor aansturen verwarming | kunnen meten tussen T=16 celcius en T=23 celcius|
# |thermistor | kamertemperatuur meten voor aansturen verwarming | een nauwkeurigheid van maximaal $\pm$ 0.5 graad celcius|
# |LDR | buitenverlichting aan als het donker is en uit als het licht is | kunnen meten tussen 100 en 300 lux (aan als lichtsterkte<200,uit als lichtsterkte>200) |
# |LDR | buitenverlichting aan als het donker is en uit als het licht is | een nauwkeurigheid van maximaal $\pm$ 10 lux  |
# |druksensor | drukverdeling voetzolen meten van een volwassen man/vrouw  | druk op de zool gemeten worden in N tussen 500N en 1000N |
# |druksensor | drukverdeling voetzolen meten van een volwassen man/vrouw  | een nauwkeurigheid van maximaal $\pm$ 10 N.|
# |druksensor | drukverdeling voetzolen meten van een volwassen man/vrouw  |  De locatie van de drukmeting kunnen bepalen in x,y-coordinaten met x en y in mm |
# |druksensor | drukverdeling voetzolen meten van een volwassen man/vrouw  |  maximaal $\pm$ 1mm resolutie in x en y richting.|
#
# Groep 55 heeft gekozen voor de LDR.

# %% [markdown]
# ## *Opdracht 3a*: Foto van de schets van jouw meetopstelling in.
# <img src="meetopstelling lichtsensor DEF-D ontwerpopdr 1.png" width="1200">
#
# Meet opstelling waar een LDR in serie staat met een 1k ohm weerstand en een knop in serie met een 1k ohm weerstand. De LDR is verbonden met pin A0 zodat de spanning over de LDR uitgelezen kan worden. De knop is verbonden met pin 2 zodat de LDR aangestuurd kan worden met de knop.

# %% [markdown]
# ## *Opdracht 3b*: Meetplan
# - 8 plekken met variërend licht (wc = donker, flits telefoon = licht) tussen de 0 en 800 lux
# - Per plek meerdere metingen, N=7
# - Per meting houden we de knop ingedrukt en meten we het licht gedurende 3 seconde, dan nemen we het gemiddelde van de meting
# - Het doel is om de lijn tussen schemering en daglicht te vinden, omdat dat het punt is waarop de tuinverlichting aan zou moeten gaan. Hierom gaan we op de gangen - - van het gebouw meten omdat daar geen direct licht is dus dan hoogst waarschijnlijk het schemerpunt dat wij zoeken het beste nabootst.

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# ### vragen
#
# 1. Welke variabelen ga je veranderen?
# 2. Over welk bereik ga je deze variabelen veranderen?
# 3. Wat ga je allemaal meten?
# 4. Hoeveel metingen ga je doen?
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?
#
# ### antwoorden
#
# 1. De lichtsterkte.
# 2. 0 tot 800 lux.
# 3. De lichtsterkte in lux en het voltage over de LDR in bits.
# 4. 8 sets van 7 metingen per plek met verschillende lichtsterkte
# 5. Ja, want wij gaan meten of deze sensor bij de gewenste lichtsterkte kan meten en hoe die dat doet.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# zie opdr 3a voor beschrijving
#
# <img src="gebouwde meetopstelling1.jpeg" width="400">
# <img src="gebouwde meetopstelling2.jpeg" width="400">
# <img src="gebouwde meetopstelling3.jpeg" width="400">

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
import numpy as np
#tafel 28
bits_1=np.array([889,877,878,867,880,882,880,878]) #gemeten hvlheid bits van de adruino
mean_bits_1=np.mean(bits_1)
lux_1=np.array([810,770,760,750,750,790,788,780]) #lichtsterkte bij meting
mean_lux_1=np.mean(lux_1)
u_bits_1=np.std(bits_1,ddof=1)/np.sqrt(len(bits_1))
u_lux_1=np.std(lux_1,ddof=1)/np.sqrt(len(lux_1))


#wc dames 
bits_3=np.array([0,8,8.5,8.5,8.5,8.5,14]) #gemeten hvlheid bits van de adruino
lux_3=np.array([0,1,2,1,1,3,3]) #lichtsterkte bij meting
mean_bits_3=np.mean(bits_3)
mean_lux_3=np.mean(lux_3)
u_bits_3=np.std(bits_3,ddof=1)/np.sqrt(len(bits_3))
u_lux_3=np.std(lux_3,ddof=1)/np.sqrt(len(lux_3))

#gang midden
bits_4=np.array([680,670,684,683.5,683,682.25,683]) #gemeten hvlheid bits van de adruino
lux_4=np.array([202,200,199,197,200,199,203]) #lichtsterkte bij meting
mean_bits_4=np.mean(bits_4)
mean_lux_4=np.mean(lux_4)
u_bits_4=np.std(bits_4,ddof=1)/np.sqrt(len(bits_4))
u_lux_4=np.std(lux_4,ddof=1)/np.sqrt(len(lux_4))

#gang hoek
bits_5=np.array([325,320,340,347,347,335,325]) #gemeten hvlheid bits van de adruino
lux_5=np.array([19,20,19,20,21,19,19]) #lichtsterkte bij meting
mean_bits_5=np.mean(bits_5)
mean_lux_5=np.mean(lux_5)
u_bits_5=np.std(bits_5,ddof=1)/np.sqrt(len(bits_5))
u_lux_5=np.std(lux_5,ddof=1)/np.sqrt(len(lux_5))

#kast einde gang
bits_6=np.array([630,638,637,629,632,635,635.5]) #gemeten hvlheid bits van de adruino
lux_6=np.array([103,103,103,102,103,103,104]) #lichtsterkte bij meting
mean_bits_6=np.mean(bits_6)
mean_lux_6=np.mean(lux_6)
u_bits_6=np.std(bits_6,ddof=1)/np.sqrt(len(bits_6))
u_lux_6=np.std(lux_6,ddof=1)/np.sqrt(len(lux_6))

#gang midden
bits_7=np.array([740,753,753,744,744,744,745]) #gemeten hvlheid bits van de adruino
lux_7=np.array([277,273,277,271,278,278,274]) #lichtsterkte bij meting
mean_bits_7=np.mean(bits_7)
mean_lux_7=np.mean(lux_7)
u_bits_7=np.std(bits_7,ddof=1)/np.sqrt(len(bits_7))
u_lux_7=np.std(lux_7,ddof=1)/np.sqrt(len(lux_7))

#stoel tafel 28
bits_8=np.array([850,843,843,838,836,836,836]) #gemeten hvlheid bits van de adruino
lux_8=np.array([580,590,610,570,580,570,560]) #lichtsterkte bij meting
mean_bits_8=np.mean(bits_8)
mean_lux_8=np.mean(lux_8)
u_bits_8=np.std(bits_8,ddof=1)/np.sqrt(len(bits_8))
u_lux_8=np.std(lux_8,ddof=1)/np.sqrt(len(lux_8))

#grond tafel 28
bits_9=np.array([805,803,802,798,802,803,802]) #gemeten hvlheid bits van de adruino
lux_9=np.array([470,477,465,480,473,480,470]) #lichtsterkte bij meting
mean_bits_9=np.mean(bits_9)
mean_lux_9=np.mean(lux_9)
u_bits_9=np.std(bits_9,ddof=1)/np.sqrt(len(bits_9))
u_lux_9=np.std(lux_9,ddof=1)/np.sqrt(len(lux_9))

bits_tot=np.array([mean_bits_1,mean_bits_3,mean_bits_4,mean_bits_5,mean_bits_6,mean_bits_7,mean_bits_8,mean_bits_9])
lux_tot=np.array([mean_lux_1,mean_lux_3,mean_lux_4,mean_lux_5,mean_lux_6,mean_lux_7,mean_lux_8,mean_lux_9])
u_bits=np.array([u_bits_1,u_bits_3,u_bits_4,u_bits_5,u_bits_6,u_bits_7,u_bits_8,u_bits_9])
u_lux=np.array([u_lux_1,u_lux_3,u_lux_4,u_lux_5,u_lux_6,u_lux_7,u_lux_8,u_lux_9])

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
import  matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %matplotlib inline

#------eerste plot van data-------##
bits_err= u_bits/100 #onzekerheid in de volatge meting van de adruino
lux_err= u_lux  #onzekerheid in de gemeten lichtsterkte
plt.figure()
plt.errorbar(bits_tot/100,(lux_tot),xerr=bits_err,yerr=lux_err,ecolor="red",ms=4,fmt="k.",label="data") #data plot
plt.xlabel(r"$voltage$ ($\frac{bits}{100}$) ")
plt.ylabel("$lichtsterkste/y$(lux)")
plt.legend()
plt.show()

#------data_fit------##
#fitfunctie:
def f(x,a,b,c):
    '''exponentiele functie om mee te fitten '''
    return a*np.exp(b*x)+c

#fitten
val,cov=curve_fit(f,bits_tot/100,(lux_tot),maxfev=10000) #gedeeld door 100 omdat de fit e^800 niet kan evalueren
a,b,c=val #waarden voor a en b
u_a,u_b,u_c=np.sqrt(np.diag(cov)) #onzekerheden in a en b door wortel van de diagonaal van de covariantie matrix
print("De fitparameters zijn bepaald op a = %.1f +/- %.1f, b = %.2f +/- %.2f en c = %.0f +/- %.0f" %(a,u_a,b,u_b,c,u_c))

#--------plot met beste fit-------#
x_plot=np.linspace(min(bits_tot)/100,max(bits_tot)/100,1000) #x_array om mee te plotten met hetzelfde domein als de bit metingen
plt.figure()
plt.errorbar(bits_tot/100,(lux_tot),xerr=bits_err,yerr=lux_err,ecolor="red",fmt="k.",label="data") #data plot
plt.plot(x_plot,f(x_plot,*val),"r--",label=r"y = %.1f $\cdot$ $e^\text{%.2fx}$ %.0f"%(a,b,c))
plt.xlabel(r"$voltage$ ($\frac{bits}{100}$) ")
plt.ylabel("$lichtsterkste$(lux)")
plt.legend()
plt.show()
# Out:
# De fitparameters zijn bepaald op a = 1.3 +/- 0.6, b = 0.73 +/- 0.05 en c = -2 +/- 16

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# Nee, alles is goed

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
# Uit de grafiek blijkt dat de sensor lichtsterkte kan meten tussen de 0 en 800 lux en dat de onzekerheden in de lichtsterkte kleiner zijn dan $\pm$ 10 lux. Er blijkt echter ook dat de spreiding van metingen rond de fit groter zijn dan wat verwacht op basis van de onzekerheden, dit kan wijzen op extra onzekerheidsbronnen die niet zijn meegenomen. Deze spreiding is echter niet zo groot dat het gevonden model invalide is, en de sensor kan alsnog duidelijk onderscheid maken in lichtsterkte van boven of onder de 200 lux. Het eerste criteria die stelt dat de sensor moet kunnen meten tussen 100 en 300 lux wordt voldaan. Het tweede criteria die stelde dat de onzekerheid in gemeten lichtsterkte kleiner moet zijn dan $\pm$ 10 lux wordt ook voldaan. Hieruit is te concluderen dat de sensor te gebruiken is om de lichtintensiteit te meten en daarmee de tuinverlichting aan te zetten bij een lichtsterkte van onder de 200 lux.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# ##### *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
#
#
# <img src="gebouwde meetopstelling1.jpeg" width="400">
# <img src="gebouwde meetopstelling2.jpeg" width="400">
# <img src="gebouwde meetopstelling3.jpeg" width="400">
#
#
# Meet opstelling waar een LDR in serie staat met een 1k ohm weerstand en een knop in serie met een 1k ohm weerstand. De LDR is verbonden met pin A0 zodat de spanning over de LDR uitgelezen kan worden. De knop is verbonden met pin 2 zodat de LDR aangestuurd kan worden met de knop.

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# ##### *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |thermistor | kamertemperatuur meten voor aansturen verwarming | kunnen meten tussen T=16 celcius en T=23 celcius|
# |thermistor | kamertemperatuur meten voor aansturen verwarming | een nauwkeurigheid van maximaal $\pm$ 0.5 graad celcius|
# |LDR | buitenverlichting aan als het donker is en uit als het licht is | kunnen meten tussen 100 en 300 lux (aan als lichtsterkte<200,uit als lichtsterkte>200) |
# |LDR | buitenverlichting aan als het donker is en uit als het licht is | een nauwkeurigheid van maximaal $\pm$ 10 lux  |
# |druksensor | drukverdeling voetzolen meten van een volwassen man/vrouw  | druk op de zool gemeten worden in N tussen 500N en 1000N |
# |druksensor | drukverdeling voetzolen meten van een volwassen man/vrouw  | een nauwkeurigheid van maximaal $\pm$ 10 N.|
# |druksensor | drukverdeling voetzolen meten van een volwassen man/vrouw  |  De locatie van de drukmeting kunnen bepalen in x,y-coordinaten met x en y in mm |
# |druksensor | drukverdeling voetzolen meten van een volwassen man/vrouw  |  maximaal $\pm$ 1mm resolutie in x en y richting.|
#
# Groep 55 heeft gekozen voor de LDR.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# ##### *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
#
#
# <img src="gebouwde meetopstelling1.jpeg" width="400">
# <img src="gebouwde meetopstelling2.jpeg" width="400">
# <img src="gebouwde meetopstelling3.jpeg" width="400">
#
#
# Meet opstelling waar een LDR in serie staat met een 1k ohm weerstand en een knop in serie met een 1k ohm weerstand. De LDR is verbonden met pin A0 zodat de spanning over de LDR uitgelezen kan worden. De knop is verbonden met pin 2 zodat de LDR aangestuurd kan worden met de knop.

# %%
import numpy as np
#tafel 28
bits_1=np.array([889,877,878,867,880,882,880,878]) #gemeten hvlheid bits van de adruino
mean_bits_1=np.mean(bits_1)
lux_1=np.array([810,770,760,750,750,790,788,780]) #lichtsterkte bij meting
mean_lux_1=np.mean(lux_1)
u_bits_1=np.std(bits_1)/np.sqrt(len(bits_1))
u_lux_1=np.std(lux_1)/np.sqrt(len(lux_1))


#wc dames 
bits_3=np.array([0,8,8.5,8.5,8.5,8.5,14]) #gemeten hvlheid bits van de adruino
lux_3=np.array([0,1,2,1,1,3,3]) #lichtsterkte bij meting
mean_bits_3=np.mean(bits_3)
mean_lux_3=np.mean(lux_3)
u_bits_3=np.std(bits_3)/np.sqrt(len(bits_3))
u_lux_3=np.std(lux_3)/np.sqrt(len(lux_3))

#gang midden
bits_4=np.array([680,670,684,683.5,683,682.25,683]) #gemeten hvlheid bits van de adruino
lux_4=np.array([202,200,199,197,200,199,203]) #lichtsterkte bij meting
mean_bits_4=np.mean(bits_4)
mean_lux_4=np.mean(lux_4)
u_bits_4=np.std(bits_4)/np.sqrt(len(bits_4))
u_lux_4=np.std(lux_4)/np.sqrt(len(lux_4))

#gang hoek
bits_5=np.array([325,320,340,347,347,335,325]) #gemeten hvlheid bits van de adruino
lux_5=np.array([19,20,19,20,21,19,19]) #lichtsterkte bij meting
mean_bits_5=np.mean(bits_5)
mean_lux_5=np.mean(lux_5)
u_bits_5=np.std(bits_5)/np.sqrt(len(bits_5))
u_lux_5=np.std(lux_5)/np.sqrt(len(lux_5))

#kast einde gang
bits_6=np.array([630,638,637,629,632,635,635.5]) #gemeten hvlheid bits van de adruino
lux_6=np.array([103,103,103,102,103,103,104]) #lichtsterkte bij meting
mean_bits_6=np.mean(bits_6)
mean_lux_6=np.mean(lux_6)
u_bits_6=np.std(bits_6)/np.sqrt(len(bits_6))
u_lux_6=np.std(lux_6)/np.sqrt(len(lux_6))

#gang midden
bits_7=np.array([740,753,753,744,744,744,745]) #gemeten hvlheid bits van de adruino
lux_7=np.array([277,273,277,271,278,278,274]) #lichtsterkte bij meting
mean_bits_7=np.mean(bits_7)
mean_lux_7=np.mean(lux_7)
u_bits_7=np.std(bits_7)/np.sqrt(len(bits_7))
u_lux_7=np.std(lux_7)/np.sqrt(len(lux_7))

#stoel tafel 28
bits_8=np.array([850,843,843,838,836,836,836]) #gemeten hvlheid bits van de adruino
lux_8=np.array([580,590,610,570,580,570,560]) #lichtsterkte bij meting
mean_bits_8=np.mean(bits_8)
mean_lux_8=np.mean(lux_8)
u_bits_8=np.std(bits_8)/np.sqrt(len(bits_8))
u_lux_8=np.std(lux_8)/np.sqrt(len(lux_8))

#grond tafel 28
bits_9=np.array([805,803,802,798,802,803,802]) #gemeten hvlheid bits van de adruino
lux_9=np.array([470,477,465,480,473,480,470]) #lichtsterkte bij meting
mean_bits_9=np.mean(bits_9)
mean_lux_9=np.mean(lux_9)
u_bits_9=np.std(bits_9)/np.sqrt(len(bits_9))
u_lux_9=np.std(lux_9)/np.sqrt(len(lux_9))

bits_tot=np.array([mean_bits_1,mean_bits_3,mean_bits_4,mean_bits_5,mean_bits_6,mean_bits_7,mean_bits_8,mean_bits_9])
lux_tot=np.array([mean_lux_1,mean_lux_3,mean_lux_4,mean_lux_5,mean_lux_6,mean_lux_7,mean_lux_8,mean_lux_9])
u_bits=np.array([u_bits_1,u_bits_3,u_bits_4,u_bits_5,u_bits_6,u_bits_7,u_bits_8,u_bits_9])
u_lux=np.array([u_lux_1,u_lux_3,u_lux_4,u_lux_5,u_lux_6,u_lux_7,u_lux_8,u_lux_9])


# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
import  matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %matplotlib inline

#------eerste plot van data-------##
bits_err= u_bits/100 #onzekerheid in de volatge meting van de adruino
lux_err= u_lux  #onzekerheid in de gemeten lichtsterkte
plt.figure()
plt.errorbar(bits_tot/100,(lux_tot),xerr=bits_err,yerr=lux_err,ecolor="red",ms=4,fmt="k.",label="data") #data plot
plt.xlabel(r"$voltage$ ($\frac{bits}{100}$) ")
plt.ylabel("$lichtsterkste/y$(lux)")
plt.legend()
plt.show()

#------data_fit------
#fitfunctie:
def f(x,a,b,c):
    '''exponentiele functie om mee te fitten '''
    return a*np.exp(b*x)+c

#fitten
val,cov=curve_fit(f,bits_tot/100,(lux_tot),maxfev=10000) #gedeeld door 100 omdat de fit e^800 niet kan evalueren
a,b,c=val #waarden voor a en b
u_a,u_b,u_c=np.sqrt(np.diag(cov)) #onzekerheden in a en b door wortel van de diagonaal van de covariantie matrix
print("De fitparameters zijn bepaald op a = %.1f +/- %.1f, b = %.2f +/- %.2f en c = %.0f +/- %.0f" %(a,u_a,b,u_b,c,u_c))

#--------plot met beste fit-------#
x_plot=np.linspace(min(bits_tot)/100,max(bits_tot)/100,1000) #x_array om mee te plotten met hetzelfde domein als de bit metingen
plt.figure()
plt.errorbar(bits_tot/100,(lux_tot),xerr=bits_err,yerr=lux_err,ecolor="red",fmt="k.",label="data") #data plot
plt.plot(x_plot,f(x_plot,*val),"r--",label=r"y = %.1f $\cdot$ $e^\text{%.2fx}$ %.0f"%(a,b,c))
plt.xlabel(r"$voltage$ ($\frac{bits}{100}$) ")
plt.ylabel("$lichtsterkste$(lux)")
plt.legend()
plt.show()
# Out:
# De fitparameters zijn bepaald op a = 1.3 +/- 0.6, b = 0.73 +/- 0.05 en c = -2 +/- 16

# %% [markdown]
# ##### *Opdracht 8*: Conclusie, leerdoel
# Uit de grafiek blijkt dat de sensor lichtsterkte kan meten tussen de 0 en 800 lux en dat de onzekerheden in de lichtsterkte kleiner zijn dan $\pm$ 10 lux. Er blijkt echter ook dat de spreiding van metingen rond de fit groter zijn dan wat verwacht op basis van de onzekerheden, dit kan wijzen op extra onzekerheidsbronnen die niet zijn meegenomen. Deze spreiding is echter niet zo groot dat het gevonden model invalide is, en sensor kan alsnog duidelijk onderscheid maken in lichtsterkte van boven of onder de 200 lux. Het eerste criteria die stelt dat de sensor moet kunnen meten tussen 100 en 300 lux wordt voldaan. Het tweede criteria die stelde dat de onzekerheid in gemeten lichtsterkte kleiner moet zijn dan $\pm$ 10 lux wordt ook voldaan. Hieruit is te concluderen dat de sensor te gebruiken is om de lichtintensiteit te meten en daarmee de tuinverlichting aan te zetten bij een lichtsterkte van onder de 200 lux.
